# %% [markdown]
# Menyiapkan akun kredensial kaggle

# %%
# !rm -rf ~/.kaggle && mkdir ~/.kaggle/

# !mv kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Import dataset dari kaggle

# %%
# !kaggle datasets download -d deepcontractor/smoke-detection-dataset
# Out:
# Downloading smoke-detection-dataset.zip to /content
#   0% 0.00/1.64M [00:00<?, ?B/s]
# 100% 1.64M/1.64M [00:00<00:00, 140MB/s]

# %% [markdown]
# Mengesktrak dataset

# %%
# !unzip /content/smoke-detection-dataset.zip
# Out:
# Archive:  /content/smoke-detection-dataset.zip
#   inflating: smoke_detection_iot.csv

# %% [markdown]
# Membaca data dan menampilkan

# %%
import pandas as pd
SmokeDect = pd.read_csv("/content/smoke_detection_iot.csv")
SmokeDect
# Out:
#        Unnamed: 0         UTC  Temperature[C]  Humidity[%]  TVOC[ppb]  \
# 0               0  1654733331          20.000        57.36          0
# 1               1  1654733332          20.015        56.67          0
# 2               2  1654733333          20.029        55.96          0
# 3               3  1654733334          20.044        55.28          0
# 4               4  1654733335          20.059        54.69          0
# ...           ...         ...             ...          ...        ...
# 62625       62625  1655130047          18.438        15.79        625
# 62626       62626  1655130048          18.653        15.87        612
# 62627       62627  1655130049          18.867        15.84        627
# 62628       62628  1655130050          19.083        16.04        638
# 62629       62629  1655130051          19.299        16.52        643
#
#        eCO2[ppm]  Raw H2  Raw Ethanol  Pressure[hPa]  PM1.0  PM2.5  NC0.5  \
# 0            400   12306        18520        939.735   0.00   0.00   0.00
# 1            400   12345        18651        939.744   0.00   0.00   0.00
# 2            400   12374        18764        939.738   0.00   0.00   0.00
# 3            400   12390        18849        939.736   0.00   0.00   0.00
# 4            400   12403        18921        939.744   0.00   0.00   0.00
# ...          ...     ...          ...            ...    ...    ...    ...
# 62625        400   13723        20569        936.670   0.63   0.65   4.32
# 62626        400   13731        20588        936.678   0.61   0.63   4.18
# 62627        400   13725        20582        936.687   0.57   0.60   3.95
# 62628        400   13712        20566        936.680   0.57   0.59   3.92
# 62629        400   13696        20543        936.676   0.57   0.59   3.90
#
#        NC1.0  NC2.5   CNT  Fire Alarm
# 0      0.000  0.000     0           0
# 1      0.000  0.000     1           0
# 2      0.000  0.000     2           0
# 3      0.000  0.000     3           0
# 4      0.000  0.000     4           0
# ...      ...    ...   ...         ...
# 62625  0.673  0.015  5739           0
# 62626  0.652  0.015  5740           0
# 62627  0.617  0.014  5741           0
# 62628  0.611  0.014  5742           0
# 62629  0.607  0.014  5743           0
#
# [62630 rows x 16 columns]

# %% [markdown]
# Informasi Data

# %%
SmokeDect.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62630 entries, 0 to 62629
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      62630 non-null  int64
#  1   UTC             62630 non-null  int64
#  2   Temperature[C]  62630 non-null  float64
#  3   Humidity[%]     62630 non-null  float64
#  4   TVOC[ppb]       62630 non-null  int64
#  5   eCO2[ppm]       62630 non-null  int64
#  6   Raw H2          62630 non-null  int64
#  7   Raw Ethanol     62630 non-null  int64
#  8   Pressure[hPa]   62630 non-null  float64
#  9   PM1.0           62630 non-null  float64
#  10  PM2.5           62630 non-null  float64
#  11  NC0.5           62630 non-null  float64
#  12  NC1.0           62630 non-null  float64
#  13  NC2.5           62630 non-null  float64
#  14  CNT             62630 non-null  int64
#  15  Fire Alarm      62630 non-null  int64
# dtypes: float64(8), int64(8)
# memory usage: 7.6 MB

# %% [markdown]
# Deskripsi statik dataset

# %%
SmokeDect.describe()
# Out:
#          Unnamed: 0           UTC  Temperature[C]   Humidity[%]     TVOC[ppb]  \
# count  62630.000000  6.263000e+04    62630.000000  62630.000000  62630.000000
# mean   31314.500000  1.654792e+09       15.970424     48.539499   1942.057528
# std    18079.868017  1.100025e+05       14.359576      8.865367   7811.589055
# min        0.000000  1.654712e+09      -22.010000     10.740000      0.000000
# 25%    15657.250000  1.654743e+09       10.994250     47.530000    130.000000
# 50%    31314.500000  1.654762e+09       20.130000     50.150000    981.000000
# 75%    46971.750000  1.654778e+09       25.409500     53.240000   1189.000000
# max    62629.000000  1.655130e+09       59.930000     75.200000  60000.000000
#
#           eCO2[ppm]        Raw H2   Raw Ethanol  Pressure[hPa]         PM1.0  \
# count  62630.000000  62630.000000  62630.000000   62630.000000  62630.000000
# mean     670.021044  12942.453936  19754.257912     938.627649    100.594309
# std     1905.885439    272.464305    609.513156       1.331344    922.524245
# min      400.000000  10668.000000  15317.000000     930.852000      0.000000
# 25%      400.000000  12830.000000  19435.000000     938.700000      1.280000
# 50%      400.000000  12924.000000  19501.000000     938.816000      1.810000
# 75%      438.000000  13109.000000  20078.000000     939.418000      2.090000
# max    60000.000000  13803.000000  21410.000000     939.861000  14333.690000
#
#               PM2.5         NC0.5         NC1.0         NC2.5           CNT  \
# count  62630.000000  62630.000000  62630.000000  62630.000000  62630.000000
# mean     184.467770    491.463608    203.586487     80.049042  10511.386157
# std     1976.305615   4265.661251   2214.738556   1083.383189   7597.870997
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.340000      8.820000      1.384000      0.033000   3625.250000
# 50%        1.880000     12.450000      1.943000      0.044000   9336.000000
# 75%        2.180000     14.420000      2.249000      0.051000  17164.750000
# max    45432.260000  61482.030000  51914.680000  30026.438000  24993.000000
#
#          Fire Alarm
# count  62630.000000
# mean       0.714626
# std        0.451596
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# Menghilangkan variabel tidak penting

# %%
SmokeDect.drop("Unnamed: 0", axis=1, inplace=True)
SmokeDect.drop("UTC", axis=1, inplace=True)
SmokeDect
# Out:
#        Temperature[C]  Humidity[%]  TVOC[ppb]  eCO2[ppm]  Raw H2  Raw Ethanol  \
# 0              20.000        57.36          0        400   12306        18520
# 1              20.015        56.67          0        400   12345        18651
# 2              20.029        55.96          0        400   12374        18764
# 3              20.044        55.28          0        400   12390        18849
# 4              20.059        54.69          0        400   12403        18921
# ...               ...          ...        ...        ...     ...          ...
# 62625          18.438        15.79        625        400   13723        20569
# 62626          18.653        15.87        612        400   13731        20588
# 62627          18.867        15.84        627        400   13725        20582
# 62628          19.083        16.04        638        400   13712        20566
# 62629          19.299        16.52        643        400   13696        20543
#
#        Pressure[hPa]  PM1.0  PM2.5  NC0.5  NC1.0  NC2.5   CNT  Fire Alarm
# 0            939.735   0.00   0.00   0.00  0.000  0.000     0           0
# 1            939.744   0.00   0.00   0.00  0.000  0.000     1           0
# 2            939.738   0.00   0.00   0.00  0.000  0.000     2           0
# 3            939.736   0.00   0.00   0.00  0.000  0.000     3           0
# 4            939.744   0.00   0.00   0.00  0.000  0.000     4           0
# ...              ...    ...    ...    ...    ...    ...   ...         ...
# 62625        936.670   0.63   0.65   4.32  0.673  0.015  5739           0
# 62626        936.678   0.61   0.63   4.18  0.652  0.015  5740           0
# 62627        936.687   0.57   0.60   3.95  0.617  0.014  5741           0
# 62628        936.680   0.57   0.59   3.92  0.611  0.014  5742           0
# 62629        936.676   0.57   0.59   3.90  0.607  0.014  5743           0
#
# [62630 rows x 14 columns]

# %% [markdown]
# Menangani Outliers

# %%
Q1 = SmokeDect.quantile(0.25)
Q3 = SmokeDect.quantile(0.75)
IQR=Q3-Q1
SmokeDect=SmokeDect[~((SmokeDect<(Q1-1.5*IQR))|(SmokeDect>(Q3+1.5*IQR))).any(axis=1)]
SmokeDect.shape
# Out:
# (35689, 14)

# %% [markdown]
# histogram masing-masing fitur

# %%
import matplotlib.pyplot as plt
SmokeDect.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# Heatmap korelasi

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
correlation_matrix = SmokeDect.corr().round(2)
sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5, )
plt.title("Correlation Matrix", size=20)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# Membagi Dataset menjadi data train dan data test

# %%
from sklearn.model_selection import train_test_split
 
X = SmokeDect.drop(["Fire Alarm"],axis =1)
y = SmokeDect["Fire Alarm"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 123)

# %% [markdown]
# Cek pembagian data

# %%
print(f'Total # of sample in whole dataset: {len(X)}')
print(f'Total # of sample in train dataset: {len(X_train)}')
print(f'Total # of sample in test dataset: {len(X_test)}')
# Out:
# Total # of sample in whole dataset: 35689
# Total # of sample in train dataset: 32120
# Total # of sample in test dataset: 3569

# %% [markdown]
# Standarisasi untuk data train

# %%
from sklearn.preprocessing import StandardScaler

features = ['Temperature[C]', 'Humidity[%]', 'TVOC[ppb]', 'eCO2[ppm]',
            'Raw H2', 'Raw Ethanol', 'Pressure[hPa]', 'PM1.0', 'PM2.5',
            'NC0.5', 'NC1.0', 'NC2.5', 'CNT']
scaler = StandardScaler()
scaler.fit(X_train[features])
X_train[features] = scaler.transform(X_train.loc[:, features])
X_train[features].head()
# Out:
#        Temperature[C]  Humidity[%]  TVOC[ppb]  eCO2[ppm]    Raw H2  \
# 3071        -0.472633    -1.147069  -1.093470  -0.457299  1.082931
# 2428         0.208332    -0.681614  -1.299921  -0.457299  1.336032
# 45494        0.788341     0.245849   0.834633  -0.457299 -0.487789
# 15757       -0.358096    -0.054111   0.755370   0.655318 -1.135432
# 30903        0.543544    -0.722988  -1.204068  -0.457299  1.492360
#
#        Raw Ethanol  Pressure[hPa]     PM1.0     PM2.5     NC0.5     NC1.0  \
# 3071      1.027737       1.248039 -0.908593 -0.904686 -0.901466 -0.903574
# 2428      1.352469       1.072855 -0.602142 -0.609359 -0.605500 -0.606203
# 45494    -0.857602      -0.891059  0.838176  0.837740  0.840947  0.842053
# 15757    -0.848144      -0.810382  0.255920  0.247087  0.253467  0.253029
# 30903     1.522718       1.190413  0.485758  0.498115  0.491575  0.490354
#
#           NC2.5       CNT
# 3071  -0.921689 -1.258038
# 2428  -0.663937 -1.342290
# 45494  0.818135  1.025675
# 15757  0.238194  0.404202
# 30903  0.495945 -0.886176

# %% [markdown]
# deskripsi statik data train setelah standarisasi

# %%
X_train[features].describe().round(4)
# Out:
#        Temperature[C]  Humidity[%]   TVOC[ppb]   eCO2[ppm]      Raw H2  \
# count      32120.0000   32120.0000  32120.0000  32120.0000  32120.0000
# mean           0.0000      -0.0000      0.0000      0.0000     -0.0000
# std            1.0000       1.0000      1.0000      1.0000      1.0000
# min           -2.3779      -3.4088     -1.3515     -0.4573     -3.0932
# 25%           -0.3252      -0.9333     -1.0750     -0.4573     -0.8600
# 50%            0.3443       0.0286      0.6706     -0.4573     -0.3389
# 75%            0.7758       0.7596      0.8697     -0.0123      0.8596
# max            1.1752       3.6419      1.3950      4.8276      3.0780
#
#        Raw Ethanol  Pressure[hPa]       PM1.0       PM2.5       NC0.5  \
# count   32120.0000     32120.0000  32120.0000  32120.0000  32120.0000
# mean       -0.0000         0.0000     -0.0000      0.0000      0.0000
# std         1.0000         1.0000      1.0000      1.0000      1.0000
# min        -1.0909        -3.4889     -2.2263     -2.2041     -2.2366
# 25%        -0.8671        -0.9302     -0.8779     -0.8752     -0.8703
# 50%        -0.7819        -0.6652      0.2866      0.2914      0.2891
# 75%         1.0088         1.1420      0.7156      0.7196      0.7119
# max         3.4427         1.6560      2.5543      2.5654      2.5567
#
#             NC1.0       NC2.5         CNT
# count  32120.0000  32120.0000  32120.0000
# mean       0.0000      0.0000      0.0000
# std        1.0000      1.0000      1.0000
# min       -2.1960     -1.9527     -1.6498
# 25%       -0.8736     -0.8573     -0.9701
# 50%        0.2888      0.3026      0.2925
# 75%        0.7120      0.6893      0.8762
# max        2.5605      2.5580      1.6144

# %% [markdown]
# Menyiapkan dataframe untuk evaluasi

# %%
models = pd.DataFrame(index=['acc'], 
                      columns=['KNN', 'RandomForest'])

# %% [markdown]
# import model KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Training data dengan KNN

# %%
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %% [markdown]
# Import model random forest dan mentraningnya

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier()
RF.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# standarisasi untuk data test

# %%
X_test.loc[:, features] = scaler.transform(X_test[features])

# %% [markdown]
# Evaluasi Model

# %%
from sklearn import metrics
y_pred = knn.predict(X_test)
Y_pred = RF.predict(X_test)
models.loc['acc','KNN'] = metrics.accuracy_score(y_test, y_pred)
models.loc['acc','RandomForest'] = metrics.accuracy_score(y_test, Y_pred)
models
# Out:
#      KNN RandomForest
# acc  1.0          1.0
